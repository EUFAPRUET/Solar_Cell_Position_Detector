# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 913.5/913.5 kB 12.2 MB/s eta 0:00:00
# ...

# %%
# !yolo detect predict \
  model=/content/drive/MyDrive/yolo_model/best.pt \
  source=/content/drive/MyDrive/videoplayback.mp4 \
  conf=0.5
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# Ultralytics 8.3.67 🚀 Python-3.11.11 torch-2.5.1+cu121 CPU (Intel Xeon 2.20GHz)
# Model summary (fused): 168 layers, 3,005,843 parameters, 0 gradients, 8.1 GFLOPs
#
# video 1/1 (frame 1/2818) /content/drive/MyDrive/test_video.mp4: 384x640 (no detections), 242.7ms
# video 1/1 (frame 2/2818) /content/drive/MyDrive/test_video.mp4: 384x640 (no detections), 144.6ms
# video 1/1 (frame 3/2818) /content/drive/MyDrive/test_video.mp4: 384x640 (no detections), 156.8ms
# video 1/1 (frame 4/2818) /content/drive/MyDrive/test_video.mp4: 384x640 (no detections), 133.6ms
# video 1/1 (frame 5/2818) /content/drive/MyDrive/test_video.mp4: 384x640 (no detections), 147.9ms
# ...

# %%
from google.colab import files
files.download("/content/runs/detect/predict/test_video.avi")
